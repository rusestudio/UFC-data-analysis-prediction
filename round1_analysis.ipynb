# %%
#hypothesis
#in early rounds, a higher proportion of leg and body strikes is related with
#the increasement of probality of KO occuring later in the fight

# %%
#use round 1 data only(early round)
#compare round 1 body&leg strikes ratio between
#-ko fight end in round 2 and round 3 (later round)
#-non ko fight for all round 1,2,3(later round)

# %%
#extract round 1 data
#1- body,leg of fighter a(win)
#2- body,leg of fighter b(lose)

body_f1 = body[]
leg_f1 = leg[]

body_f2 = body[]
leg_f2 = leg[]
